# %% [markdown]
# <a href="https://colab.research.google.com/github/PhonSobon/Khmer_OCR/blob/main/khmer_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import torch
import skimage
import albumentations
import cv2
from PIL import Image

# %%
from datasets import load_dataset

ds = load_dataset("seanghay/khmer-dictionary-44k", split="train")
# Out:
# README.md:   0%|          | 0.00/503 [00:00<?, ?B/s]
# (…)-00000-of-00001-2daca7aaef973ba0.parquet:   0%|          | 0.00/4.72M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/44706 [00:00<?, ? examples/s]

# %%
# prompt: show all data in description

print(ds)
print(ds.features)
print(ds[0])
print(ds[:5])
print(ds.info)
print(ds.description)
print(ds.citation)
print(ds.homepage)
print(ds.license)
print(ds.builder_name)
print(ds.config_name)
print(ds.version)
print(ds.num_rows)
print(ds.num_columns)
print(ds.column_names)
print(ds.shape)
print(ds.dataset_size)
print(ds.size_in_bytes)
print(ds.split)
print(ds.data)
# Out:
# Dataset({
#     features: ['word', 'pos', 'pro', 'definition', 'example'],
#     num_rows: 44706
# })
# {'word': Value(dtype='string', id=None), 'pos': Value(dtype='string', id=None), 'pro': Value(dtype='string', id=None), 'definition': Value(dtype='string', id=None), 'example': Value(dtype='string', id=None)}
# {'word': 'ក', 'pos': 'ន.', 'pro': '[ក]', 'definition': 'តួអក្សរទី១ក្នុងវគ្គទី១នៃអក្ខរក្រមព្យញ្ជនៈខ្មែរ។\xa0តួអក្សរនេះមានឈ្មោះថា\xa0ក\xa0ហើយតាងឱ្យព្យញ្ជនៈ /ក/\xa0មានអក្ខរសូរអន្តរជាតិ\xa0[k]\xa0ជាកណ្ឋជៈ មានសំឡេងក្នុងឋានបំពង់ក ជាសិថិល អឃោសៈ។', 'example': ''}
# {'word': ['ក', 'ក', 'ក', 'ក៏', 'កក'], 'pos': ['ន.', 'កិ.', 'ន.', 'ឈ.', 'គុ.កិ., គុ.'], 'pro': ['[ក]', '[ក]', '[ក]', '[ក]', '[កក]'], 'definition': ['តួអក្សរទី១ក្នុងវគ្គទី១នៃអក្ខរក្រមព្យញ្ជនៈខ្មែរ។\xa0តួអក្សរនេះមានឈ្មោះថា\xa0ក\xa0ហើយតាងឱ្យព្យញ្ជនៈ /ក/\xa0មានអក្ខរសូរអន្តរជាតិ\xa0[k]\xa0ជាកណ្ឋជៈ មានសំឡេងក្នុងឋានបំពង់ក ជាសិថិល អឃោសៈ។', 'តាំងផ្ដើម, តាំងធ្វើ', 'អវយវៈដែលតពីក្បាលទៅស្មា ឬទៅខ្លួននៃមនុស្សសត្វ', 'ពាក្យជាសន្ធានមានសំឡេងកញ្ឆក់ខ្លីសម្រាប់និយាយតប្រយោគដោយឡែក', 'កុះករ, តាន់តាប់, ជុំជិត, កុញ, ត្រៀបត្រា'], 'example': ['', 'កសាង, កកើត, កចេតិយ, កភូមិ។', 'កមនុស្ស, កមាន់។', 'អ្នកក៏ទៅ, ខ្ញុំក៏ទៅ, ធ្វើដូច្នេះក៏បាន, របស់នេះរូបក៏ល្អ តម្លៃក៏ថោក។', 'មើលទៅឃើញមនុស្សកក, ឈរកក។']}
# DatasetInfo(description='', citation='', homepage='', license='', features={'word': Value(dtype='string', id=None), 'pos': Value(dtype='string', id=None), 'pro': Value(dtype='string', id=None), 'definition': Value(dtype='string', id=None), 'example': Value(dtype='string', id=None)}, post_processed=None, supervised_keys=None, builder_name='parquet', dataset_name='khmer-dictionary-44k', config_name='default', version=0.0.0, splits={'train': SplitInfo(name='train', num_bytes=12024480, num_examples=44706, shard_lengths=None, dataset_name='khmer-dictionary-44k')}, download_checksums={'hf://datasets/seanghay/khmer-dictionary-44k@97621722c6d6c928aa0eb16fc0d533a4cfb6a01e/data/train-00000-of-00001-2daca7aaef973ba0.parquet': {'num_bytes': 4722011, 'checksum': None}}, download_size=4722011, post_processing_size=None, dataset_size=12024480, size_in_bytes=16746491)
#
#
#
#
# parquet
# default
# 0.0.0
# 44706
# 5
# ['word', 'pos', 'pro', 'definition', 'example']
# (44706, 5)
# 12024480
# 16746491
# train
# MemoryMappedTable
# word: string
# pos: string
# pro: string
# definition: string
# example: string
# ----
# word: [["ក","ក","ក","ក៏","កក",...,"កាល់","កាលកិរិយា","កាលកំណត់","កាលដែល","កាលៈទេសៈ"],["កាលបរិច្ឆេទ","កាលប្បវត្តិ","កាលប្រវត្តិ","កាលប្រវត្តិវិទ្យា","កាលវសាន",...,"ក្របួច","ក្របៀត","ក្របៀត","ក្របែល","ក្របៅ"],...,["រអូចរអើប","រអូចរអើម","រអើម","រអេៈរអុ","រាគន្លង",...,"ស្រងាំ","ស្រណោះ","ស្រទន់","ស្រប","ស្រព"],["ស្រពោន","ស្រមោល","ស្រយាល","ស្រវាវេច","ស្រវាំង",...,"អ៊ឹម","អ៊‌ឺត","អ៊‌ឺះ!","អ៊ុត","អ៊ុត"]]
# pos: [["ន.","កិ.","ន.","ឈ.","គុ.កិ., គុ.",...,"កិ.","ន.","ន.","ឈ.","ន."],["ន.","ន.","ន.","ន.","ន.",...,"កិ.","ន.","កិ.","កិ.","ន."],...,["គុ.កិ.","កិ.","កិ., គុ.","ឧ.","គុ.កិ.",...,"គុ.","កិ.","គុ.","គុ.កិ.","កិ."],["គុ.","ន.","គុ.កិ.","","កិ.",...,"សព្វ.","ន.","ឧ.","កិ.","កិ."]]
# pro: [["[ក]","[ក]","[ក]","[ក]","[កក]",...,"[កាល់]","[កា-ឡៈ-កិ-រ៉ិ-យ៉ា]","[កាល-កំ-ណត់]","[កាល-ដែល]","[កា-ឡៈ-ទេ-សៈ]"],["[កា-ឡៈ-ប៉ៈ-រ៉ិ-ឆែត]ឬ[កាល-ប៉ៈ-រ៉ិ-ឆែត]","[កា-ឡាប់-ប៉ៈ-វ័ត]","[កា-ឡៈ-ប្រ-វ័ត]ឬ[កាល-ប្រ-វ័ត]","[កា-ឡៈ-ប្រ-វ័ត-វិត-ទ្យា]ឬ[កាល-ប្រ-វ័ត-វិត-ទ្យា]","[កា-ឡៈ-វៈ-សាន]",...,"[ក្រ-បួច]","[ក្រ-បៀត]","[ក្រ-បៀត]","[ក្រ-បែល]","[ក្រ-បៅ]"],...,["[រ-អូច-រ-អើប]","[រ-អូច-រ-អើម]","[រ-អើម]","[រ-អេៈ-រ-អុ]","[រា-គន់-លង]",...,"[ស្រ-ង៉ាំ]","[ស្រ-ណោះ]","[ស្រ-ទន់]","[ស្រប]","[ស្រប់]"],["[ស្រ-ពោន]","[ស្រ-ម៉ោល]","[ស្រ-យ៉ាល]","[ស្រ-វ៉ា-វេច]","[ស្រ-វ៉ាំង]",...,"[អ៊ឹម]","[អ៊ឺត]","[អ៊ឺស]","[អ៊ុត]","[អ៊ុត]"]]
# definition: [["តួអក្សរទី១ក្នុងវគ្គទី១នៃអក្ខរក្រមព្យញ្ជនៈខ្មែរ។ តួអក្សរនេះមានឈ្មោះថា ក ហើយតាងឱ្យព្យញ្ជនៈ /ក/ មានអក្ខរសូរអន្តរជាតិ [k] ជាកណ្ឋជៈ មានសំឡេងក្នុងឋានបំពង់ក ជាសិថិល អឃោសៈ។","តាំងផ្ដើម, តាំងធ្វើ","អវយវៈដែលតពីក្បាលទៅស្មា ឬទៅខ្លួននៃមនុស្សសត្វ","ពាក្យជាសន្ធានមានសំឡេងកញ្ឆក់ខ្លីសម្រាប់និយាយតប្រយោគដោយឡែក","កុះករ, តាន់តាប់, ជុំជិត, កុញ, ត្រៀបត្រា",...,"ខារខាំងមិនឱ្យច្រឡូកច្រឡំលាយគ្នា","សេចក្ដីស្លាប់","ពេលវេលាមួយដែលកិច្ចការត្រូវបំពេញរួចរាល់នៅមុនឬនៅត្រឹមពេលនោះ។","ពេលដែល, គ្រាដែល, ខណៈដែល","កាលសម័យរបស់ស្រុកទេស; កាលនិងប្រទេស, លក្ខខណ្ឌនៃពេលវេលា ទីកន្លែងជាដើម ដែលអម ឬមានឥទ្ធិពលលើព្រឹត្តិការណ៍ ឬលក្ខខណ្ឌ"],["ការកំណត់ពេល, ការកម្រិតនៃថ្ងៃខែឆ្នាំ។","(ម.ព. កាលប្រវត្តិ)។","កំណត់ត្រាប្រវត្តិសាស្ត្រតាមលំដាប់ពេលវេលា","វិទ្យាសាស្ត្រដែលសិក្សាអំពីកាលប្រវត្តិ។","កាលកំណត់ចុងក្រោយនៃសុពលភាព",...,"ចាប់រួបក្រសោបបួង","ខ្នាតបុរាណខ្មែរដែលមានប្រវែងមួយចង្អុលដៃ ឬ១២គ្រាប់ស្រូវ។","កៀបអ្វីមួយយ៉ាងតឹងនៅចន្លោះដៃ ឬចន្លោះជើង។","កាប់រំលំ ឬកាប់ផ្ដាច់","ឈ្មោះឈើមួយប្រភេទ មានផ្លែបរិភោគបាន។ អ្នកស្រុកធ្លាប់ជឿមកថា កាលណាត្រីព្រលូងស៊ីផ្លែក្របៅ សាច់ត្រីនោះកាលណាគេបរិភោគទៅនឹងបណ្ដាលជាពិសពុល។"],...,["ដែលហើបសេចក្ដីកំបាំងឬការសម្ងាត់លេចឮបន្តិចៗ","(ព.ប្រ.) រង្កៀសចិត្តរអូច, មិនស៊ប់ចិត្ត, រកកល់ស្អប់","(ព.ប្រ.) ស្អប់ខ្ពើមមិនចង់នឹកនាដល់","សូរឮអេៈអុៗរឿយៗ។","(ព.ប្រ.) ប្រកែកឬដោះដៃមិនហ៊ានតស៊ូឬមិនហ៊ានទទួលភារៈ។",...,"(ព.ប្រ.) ដែលស្លៀកពាក់សមរម្យមិនរន្ទាលពេក","(ព.សា.) នឹកឃើញ, នឹកដល់, រឭកដល់","ដែលស្រទំយ៉ាងទន់","ដែលបណ្ដោយទន្ទឹមគ្នា","(រ.ស.) លាង, ជម្រះ, លុបឱ្យជ្រះ ឱ្យស្អាត"],["ដែលមិនស្រស់បស់, មិនរីករាយ, ក្រៀមក្រំ","ស្លាកស្នាម, អ្វីដែលដិតដាម បន្សល់ទុកពីអតីតកាល","ដែលធ្លាក់ឆ្ងាយ ឬដែលធ្លាក់ពីទីខ្ពស់លន្លឹម","(ព.ប្រ.) វាតអាទិ៍យកតែម្នាក់ឯង ដោយឥតខ្មាស។","(ព.ប្រ.) ភ័ន្តស្មារតីព្រោះសេចក្ដីឆ្មើងឬព្រោះងប់ចិត្តខុសប្រក្រតី",...,"អ៊ំសាច់ថ្លៃ, ប្រពន្ធរបស់ប៉ិ, ពាក្យសម្រាប់ហៅសាច់ថ្លៃឋានៈស្មើគ្នាសន្មតដូចកូនត្រូវហៅ។","ឈ្មោះក្រួចមួយប្រភេទ មាឌធំជាងក្រួចឯទៀត រងាវឬយំឮសូរ អ៊‌ឺតៗ ជាបក្សីដេញធ្នាក់","ពាក្យលាន់មាត់ដោយប្រឹងលើករបស់ធ្ងន់ជាដើម","សង្កត់ដោយកញ្ចប់ដីខ្សាច់ក្ដៅជាដើមឱ្យរាបស្លាប់សាច់","(ព.ប្រ.) ស្ដីបន្ទោសជ្រក់ជ្រេញកម្ដៅចិត្តរាល់វេលាងើបមុខពុំរួច ឬសង្កត់សង្កិនញាំញីជានិច្ច"]]
# example: [["","កសាង, កកើត, កចេតិយ, កភូមិ។","កមនុស្ស, កមាន់។","អ្នកក៏ទៅ, ខ្ញុំក៏ទៅ, ធ្វើដូច្នេះក៏បាន, របស់នេះរូបក៏ល្អ តម្លៃក៏ថោក។","មើលទៅឃើញមនុស្សកក, ឈរកក។",...,"គោកាល់ហ្វូង។","ធ្វើកាលកិរិយា។","","កាលដែលបិតាធ្វើមរណកាលទៅ គាត់ពុំបានផ្ដែផ្ដាំអ្វីឡើយ។","មុននឹងប្រកបមុខរបរផ្សេងៗ គប្បីពិចារណាលៃលកមើលឱ្យសមរម្យទៅតាមកាលៈទេសៈ។"],["","","កាលប្រវត្តិនៃប្រទេសកម្ពុជា។","","បណ្ណសងតាមបញ្ជាមានកាលវសាន ៩០ថ្ងៃចាប់ពីថ្ងៃដែលបានទទួល។",...,"ក្របួចមាត់ថង់, ក្របួចមាត់ការុង, ក្របួចចុងស្មៅ។","","","ក្របែលឈើ, ក្របែលឫស្សី។",""],...,["ការនុះមិនទាន់ប្រាកដទេ ទើបនឹងឮរអូចរអើបបន្តិចបន្តួច។","ចេះតែរអូចរអើមចិត្ត។","រអើមចិត្ត ឬ ចិត្តរអើម។","","",...,"ស្រីស្រស់ស្រងាំ ...។","ស្រណោះពេលព្រះអាទិត្យរៀបអស្ដង្គត។","មេឃស្រទន់។","ផ្ដេកសសរស្របគ្នា។","ស្រពព្រះភ័ក្ដ្រ គឺជម្រះព្រះភ័ក្ដ្រ (លុបលាងមុខឱ្យស្អាត)។"],["មុខស្រពោន។","ស្រមោលស្នេហ៍, ស្រមោលអនុស្សាវរីយ។","ធ្លាក់ស្រយាល។","","ស្រវាំងមិនស្គាល់កូនប្រពន្ធ។",...,"","ក្រួចអ៊‌ឺត។","លាន់មាត់ឮអ៊‌ឺះ! (ឮ អ៊‍ឹះ! ប៉ុន្តែសូរវែង)។","អ៊ុតស្លឹកសង្កែ។","បើព្រឹកអ៊ុត ល្ងាចអ៊ុតយ៉ាងនេះ នឹងទ្រាំនៅតទៅទៀតមិនកើតទេ! (ព.សា.)។"]]
